# %% [markdown]
# For all the files in a folder. Integrate from fermi level to top energy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import glob

# %%
fdir = r"/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/"

csvf = glob.glob(f"{fdir}/*/*.csv")
folders = glob.glob(f"{fdir}/*/")

# %%
csvf
# Out:
# ['/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=11/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=13/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=15/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=17/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=19/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=21/disc_spatial_ldos.csv',
#  '/mnt/c/Users/ander/OneDrive/Documents/GitHub/QPI-Scattering/TBCalcs/DiscreteLDOS/bsublattice_10x10/sep=3/continous_ldos.csv',
# ...
