# %% [markdown]
# tbinding_ldos.ipynb
#
# Authors: Anderson Steckler, Sergey Pershoguba
#
# Calculating spatial Local Density of States of graphene lattice with added disorder.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

import pybinding as pb
from pybinding.repository import graphene

from tqdm import tqdm

import psutil
import os

# %% [markdown]
# Create folder to save plots

# %%
# !mkdir output
# Out:
# mkdir: cannot create directory ‘output’: File exists

# %% [markdown]
# Limit CPU to 75% so i can still use my pc

# %% [markdown]
# ### Create the material and any defects

# %%
# Basis Vectors
a1 = graphene.a * np.array([1, np.sqrt(3)])/2
a2 = graphene.a * np.array([-1, np.sqrt(3)])/2
a3 = graphene.a * np.array([1, 0])

at = graphene.a/np.sqrt(3) # Distance between A and B sublattices

# Separation
n = 3

def pv(x, y, sigma):
  return 1/((sigma ** 2) * 2 * np.pi) * np.exp(-(x ** 2 + y ** 2) / (2*(sigma**2)))

@pb.onsite_energy_modifier
def potential(x, y):
    #return -3*np.exp(-(x**2+(y-at/2)**2)/(at)**2)
  return pv(x-(n*at*np.tan(np.pi/3)), y+at/2, 1e-2) + pv(x+(n*at*np.tan(np.pi/3)), y+at/2, 1e-2)

# Create tightbinding model
model = pb.Model(graphene.monolayer(), pb.rectangle(50, 50), potential)

# %%
# Plotting energy ontop of lattice
model.plot()
xlin=np.linspace(-1, 1, 100)
ylin = np.linspace(-1, 1, 100)



X, Y = np.meshgrid(xlin, ylin)

plt.axhline(0)
plt.axvline(0)
plt.pcolormesh(X, Y, potential(X, Y), alpha=0.5)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.title("Defect on Lattice")

plt.savefig("output/defect_on_lattice.png")

# %% [markdown]
# ### LDOS with KPM

# %% [markdown]
# ### Discrete Spatial LDOS at fixed energy

# %%
size = 20 # half of lateral size
energies = np.array([0.2]) # eV

kpm = pb.kpm(model)

spatial_ldos = kpm.calc_spatial_ldos(energies,
                                     broadening=0.1, #eV
                                     shape=pb.rectangle(size*2))
# Out:
# Computing KPM moments...
# Progress  0% [                                ] Elapsed: 0:00:00 / ETA: --:--:--
# Progress 100% [////////////////////////////////] Elapsed: 0:06:26 / ETA: 0:00:00

# %%
# Plotting
fig2, ax2 = plt.subplots()

smap = spatial_ldos.structure_map(energies[0])
smap.plot(site_radius=(0.02, 0.15))
ax2.set_xlim(-5, 5)
ax2.set_ylim(-5, 5)
ax2.set_xlabel("x (nm)")
ax2.set_ylabel("y (nm)")
ax2.set_title("Discrete LDOS at 0.2 eV")

fig2.savefig("output/discrete_ldos.png")

# %% [markdown]
# ### Continuous Spatial LDOS

# %%
(X, Y, Z) = smap.spatial_map.positions
psi2 = smap.data

mesh_size = 250
x, y = np.meshgrid(np.linspace(-5, 5, mesh_size),
                   np.linspace(-5, 5, mesh_size))
z = x*0

# Interpolate by gaussian
# Every site impacts the points like a gaussian
# See Slater-Koster tightbinding for graphene band structure
for (X, Y, psi2) in tqdm(zip(X, Y, psi2)):
  z += psi2*np.exp(-((x-X)**2+(y-Y)**2)/(at)**2)

z_min, z_max = 0, np.abs(z).max()
# Out:
# 49931it [01:03, 791.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 12
#       7 z = x*0
#       9 # Interpolate by gaussian
#      10 # Every site impacts the points like a gaussian
#      11 # See Slater-Koster tightbinding for graphene band structure
# ---> 12 for (X, Y, psi2) in tqdm(zip(X, Y, psi2)):
#      13   z += psi2*np.exp(-((x-X)**2+(y-Y)**2)/(at)**2)
#      15 z_min, z_max = 0, np.abs(z).max()
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:1191, in tqdm.__iter__(self)
#    1189 dt = cur_t - last_print_t
#    1190 if dt >= mininterval and cur_t >= min_start_t:
# -> 1191     self.update(n - last_print_n)
#    1192     last_print_n = self.last_print_n
#    1193     last_print_t = self.last_print_t
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/tqdm/utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniconda3/envs/mqpi/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
np.min(np.abs(z))
# Out:
# 0.008981183369330716

# %%
fig3, ax3 = plt.subplots()

c = ax3.pcolormesh(x, y, np.abs(z), cmap='bwr', vmin=0.008, vmax=z_max)
ax3.axis([x.min(), x.max(), y.min(), y.max()])
fig3.colorbar(c, ax=ax3, label="U (eV)")
ax3.set_aspect("equal")
ax3.set_xlim(-5, 5)
ax3.set_ylim(-5, 5)

ax3.set_title("Continuous Spatial LDOS")
fig3.savefig("output/continuous_ldos.png")

# %%
df = pd.DataFrame()

df['x'] = x.flatten()
df['y'] = y.flatten()
df['Re(z)'] = np.real(z).flatten()
#df['Im(z)'] = np.imag(z).flatten()
#df['MeshSize'] = mesh_size
#df['DiscreteSize'] = size
#df['LDOS Energy'] = energies[0]

df.to_csv("output/continous_ldos.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 11
#       5 df['Re(z)'] = np.real(z).flatten()
#       6 #df['Im(z)'] = np.imag(z).flatten()
#       7 #df['MeshSize'] = mesh_size
#       8 #df['DiscreteSize'] = size
#       9 #df['LDOS Energy'] = energies[0]
# ---> 11 df.to_csv("output/continous_ldos.csv").drop(['unnamed 0'],axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'drop'
