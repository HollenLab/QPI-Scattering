# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

import pybinding as pb
from pybinding.repository import group6_tmd

from tqdm import tqdm

import psutil
import os

# %% [markdown]
# Create folder to save plots

# %%
# !mkdir output

# %% [markdown]
# ### Create the material and any defects

# %%
# Creating vacancy
def vacancy(position, radius):
    @pb.site_state_modifier
    def modifier(state, x, y):
        x0, y0 = position
        state[(x-x0)**2 + (y-y0)**2 < radius**2] = False
        return state
    return modifier

# Create tightbinding model
#model = pb.Model(graphene.monolayer(), 
#                 pb.rectangle(50, 50), 
#                 vacancy(position=[-10 * n * h, at/2], radius=0.1),
#                 vacancy(position=[10 * n * h, -at/2], radius=0.05))

model = pb.Model(group6_tmd.monolayer_3band("MoSe2"), pb.translational_symmetry())

# %%
# Plotting energy ontop of lattice
#model.onsite_map.plot_contourf()
#pb.pltutils.colorbar(label="U (eV)")
model.plot()
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
#plt.plot(2 * h, at/2, marker='x', color='red')
plt.title("Defect on Lattice")

plt.savefig("output/defect_on_lattice.png")

# %%
solver = pb.solver.lapack(model)

k_points = model.lattice.brillouin_zone()
gamma = [0, 0]
k = k_points[0]
m = (k_points[0] + k_points[1]) / 2

plt.figure(figsize=(6.7, 2.3))

plt.subplot(121, title="MoSe2 3-band model band structure")
bands = solver.calc_bands(gamma, k, m, gamma)
bands.plot(point_labels=[r"$\Gamma$", "K", "M", r"$\Gamma$"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 11
#       8 plt.figure(figsize=(6.7, 2.3))
#      10 plt.subplot(121, title="MoS2 3-band model band structure")
# ---> 11 bands = solver.calc_bands(gamma, k, m, gamma)
#      12 bands.plot(point_labels=[r"$\Gamma$", "K", "M", r"$\Gamma$"])
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:310, in Solver.calc_bands(self, k0, k1, step, point_labels, *ks)
#     308 k_points = [np.atleast_1d(k) for k in (k0, k1) + ks]
#     309 k_path = results.make_path(*k_points, step=step, point_labels=point_labels)
# --> 310 return self.calc_bands_path(k_path)
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:328, in Solver.calc_bands_path(self, k_path)
#     326 for k in k_path:
#     327     self.set_wave_vector(k)
# --> 328     bands.append(self.eigenvalues)
#     330 return results.Bands(k_path, np.vstack(bands))
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:59, in Solver.eigenvalues(self)
#      56 @property
#      57 def eigenvalues(self) -> np.ndarray:
#      58     """1D array of computed energy states"""
# ---> 59     return self.impl.eigenvalues
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:490, in _SolverPythonImpl.eigenvalues(self)
#     488 @property
#     489 def eigenvalues(self) -> np.ndarray:
# --> 490     self.solve()
#     491     return self.vals
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:504, in _SolverPythonImpl.solve(self)
#     500     return
#     502 start_time = time.time()
# --> 504 self.vals, self.vecs = self.solve_func(self.model.hamiltonian, **self.kwargs)
#     505 idx = self.vals.argsort()
#     506 self.vals = self.vals[idx]
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/pybinding/solver.py:537, in lapack.<locals>.solver_func(hamiltonian, **kw)
#     535 def solver_func(hamiltonian: csr_matrix, **kw) -> Tuple[np.ndarray, np.ndarray]:
#     536     from scipy.linalg import eigh
# --> 537     return eigh(hamiltonian.toarray(), **kw)
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/scipy/_lib/deprecation.py:213, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     211 extra_args = len(args) - len(all_args)
#     212 if extra_args <= 0:
# --> 213     return f(*args, **kwargs)
#     215 # extra_args > 0
#     216 args_msg = [
#     217     f"{name}={arg}"
#     218     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#     219 ]
#
# File ~/miniconda3/envs/wsl_qpi/lib/python3.12/site-packages/scipy/linalg/_decomp.py:560, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     557         lwork_args = {'lwork': lw}
#     559     drv_args.update({'lower': lower, 'compute_v': 0 if _job == "N" else 1})
# --> 560     w, v, *other_args, info = drv(a=a1, **drv_args, **lwork_args)
#     562 else:  # Generalized problem
#     563     # 'gvd' doesn't have lwork query
#     564     if driver == "gvd":
#
# KeyboardInterrupt:

# %% [markdown]
# ### LDOS with KPM

# %%
kpm = pb.kpm(model) # Kernal polynomial method. Instead of diagonalizing, explands everything in terms of Chebyshev polynomials

# Calculate LDOS close and far away
positions = [[0,0]]
sublattices = ['B'] # Which sub lattice we want to calculate for

for p, s in zip(positions, sublattices):
  print(p)
  ldos = kpm.calc_ldos(energy=np.linspace(-9, 9, 100), broadening=0.1, position=p)
  ldos.plot(label=s + " at {pa:.2f},{pb:.2f}".format(pa=p[0], pb=p[1]))

pb.pltutils.legend()

plt.savefig("output/energy_ldos.png")
# Out:
# [0, 0]
# Computing KPM moments...
# Progress 100% [////////////////////////////////] Elapsed: 0:00:00 / ETA: 0:00:00

# %% [markdown]
# ### Discrete Spatial LDOS at fixed energy

# %%
size = 20 # half of lateral size
energies = np.array([0.2]) # eV

spatial_ldos = kpm.calc_spatial_ldos(np.linspace(-3, 3, 100),
                                     broadening=0.1, #eV
                                     shape=pb.rectangle(size*2))
# Out:
# Computing KPM moments...
# Progress  0% [                                ] Elapsed: 0:00:00 / ETA: --:--:--
# Progress 100% [////////////////////////////////] Elapsed: 0:03:20 / ETA: 0:00:00

# %%
# Plotting
fig2, ax2 = plt.subplots()

smap = spatial_ldos.structure_map(energies[0])
smap.plot(site_radius=(0.02, 0.15))
ax2.set_xlim(-5, 5)
ax2.set_ylim(-5, 5)
ax2.set_xlabel("x (nm)")
ax2.set_ylabel("y (nm)")
ax2.set_title("Discrete LDOS at 0.2 eV")

fig2.savefig("output/discrete_ldos.png")

# %% [markdown]
# ### Continuous Spatial LDOS

# %%
(X, Y, Z) = smap.spatial_map.positions
psi2 = smap.data

mesh_size = 1000
x, y = np.meshgrid(np.linspace(-10, 10, mesh_size),
                   np.linspace(-10, 10, mesh_size))
z = x*0

# Interpolate by gaussian
# Every site impacts the points like a gaussian
# See Slater-Koster tightbinding for graphene band structure
for (X, Y, psi2) in tqdm(zip(X, Y, psi2)):
  z += psi2*np.exp(-((x-X)**2+(y-Y)**2)/(at)**2)

z_min, z_max = 0, np.abs(z).max()
# Out:
# 61098it [17:56, 56.76it/s]

# %%
fig3, ax3 = plt.subplots()

c = ax3.pcolormesh(x, y, np.abs(z), cmap='bwr', vmin=z_min, vmax=z_max)
ax3.axis([x.min(), x.max(), y.min(), y.max()])
fig3.colorbar(c, ax=ax3, label="U (eV)")
ax3.set_aspect("equal")
#ax3.set_xlim(-5, 5)
#ax3.set_ylim(-5, 5)

ax3.set_title("Continuous Spatial LDOS")
fig3.savefig("output/continuous_ldos.png")

# %%
df = pd.DataFrame()

df['x'] = x.flatten()
df['y'] = y.flatten()
df['Re(z)'] = np.real(z).flatten()
#df['Im(z)'] = np.imag(z).flatten()
#df['MeshSize'] = mesh_size
#df['DiscreteSize'] = size
#df['LDOS Energy'] = energies[0]

df.to_csv("output/continous_ldos.csv", index=False)
